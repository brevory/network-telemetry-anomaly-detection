# %% [markdown]
# # Data Audit
#
# Review discovered datasets, node files, and ground-truth windows.

# %%
import pandas as pd
from pathlib import Path

root = Path('..')
data_inventory = pd.read_csv(root / 'results' / 'data_inventory.csv')
ground_truth_inventory = pd.read_csv(root / 'results' / 'ground_truth_inventory.csv')
display(data_inventory.head(20))
display(ground_truth_inventory)
