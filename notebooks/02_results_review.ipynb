# %% [markdown]
# # Results Review
#
# Review metrics and generated alarms after running experiments.

# %%
import pandas as pd
from pathlib import Path

root = Path('..')
metrics = pd.read_csv(root / 'results' / 'metrics_summary.csv')
alarms = pd.read_csv(root / 'results' / 'alarms.csv')
display(metrics.sort_values(['f1', 'recall', 'precision'], ascending=False).head(20))
display(alarms.head(20))
